# %%
#from ipynb.fs.defs.pipeline import dataset_pipeline

import pandas as pd
import numpy as np
from pandas import Series, DataFrame
#import dill
import pickle
import gzip

#Librerias
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer, TfidfTransformer, CountVectorizer
from sklearn.pipeline import FeatureUnion
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import TruncatedSVD
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_validate

# Classifiers
#import lightgbm as lgb
from sklearn.ensemble import RandomForestClassifier
#from sklearn.naive_bayes import MultinomialNB
#from sklearn.linear_model import LogisticRegression

# %%
pickle_file = open('./dataframe_preproc.pkl','rb')

df = pickle.load(pickle_file)
df = df.sample(frac=1, random_state=12).copy() # mezclo los datos para que los subsambling sean aleatorios
pickle_file.close()

df=df[:3000]

# %%
df.head(10)
# Out:
#           titleType                                 primaryTitle  \
# tconst
# tt3171176     movie                                  Painkillers
# tt3202670     movie                                    96 heures
# tt2889050     movie                        La mossa del pinguino
# tt6493644     movie                          Birds Without Names
# tt3635300     movie                               Girls for Sale
# tt4844348     movie                                        Spear
# tt5582876     movie                       In the Name of Ben Hur
# tt5544384     movie  Sword Art Online: The Movie - Ordinal Scale
# tt5797820     movie           Real: O Plano por Trás da História
# tt4331318     movie                                    Heat Wave
#
#                                         originalTitle  isAdult  startYear  \
# tconst
# tt3171176                                 Painkillers      0.0     2015.0
# tt3202670                                   96 heures      0.0     2014.0
# tt2889050                       La mossa del pinguino      0.0     2013.0
# tt6493644     Kanojo ga sono na wo shiranai toritachi      0.0     2017.0
# tt3635300                              Girls for Sale      0.0     2016.0
# tt4844348                                       Spear      0.0     2015.0
# tt5582876                      In the Name of Ben Hur      0.0     2016.0
# tt5544384  Gekijo-ban Sword Art Online: Ordinal Scale      0.0     2017.0
# tt5797820          Real: O Plano por Trás da História      0.0     2017.0
# tt4331318                               Coup de chaud      0.0     2015.0
#
#            endYear  runtimeMinutes                      genres  \
# tconst
# tt3171176      NaN           102.0      Action,Sci-Fi,Thriller
# tt3202670      NaN            96.0                    Thriller
# tt2889050      NaN            90.0                      Comedy
# tt6493644      NaN           123.0               Drama,Mystery
# tt3635300      NaN            87.0                       Drama
# tt4844348      NaN            84.0                       Drama
# tt5582876      NaN            89.0                      Action
# tt5544384      NaN           119.0  Action,Adventure,Animation
# tt5797820      NaN            96.0               Drama,History
# tt4331318      NaN           102.0                 Crime,Drama
#
#                                        principal_nconst_list  \
# tconst
# tt3171176  nm0220406,nm0671886,nm2788229,nm0272173,nm1570...
# tt3202670  nm0702467,nm0487254,nm0034390,nm0856500,nm0175...
# tt2889050  nm0230510,nm0502412,nm0578633,nm0266890,nm0268...
# tt6493644  nm0847570,nm0008369,nm2344050,nm2797973,nm1066...
# tt3635300  nm3615754,nm5448949,nm6394971,nm2733090,nm6394...
# tt4844348  nm0633354,nm0669853,nm3638200,nm3973384,nm7444...
# tt5582876  nm2106033,nm5956650,nm1345685,nm2481125,nm5557...
# tt5544384  nm4441200,nm4303311,nm2955927,nm2821488,nm2971...
# tt5797820  nm0251896,nm3932366,nm2142737,nm0996588,nm2131...
# tt4331318  nm0150102,nm0201669,nm1687610,nm3588254,nm0290...
#
#            principal_nconst_count  directors  \
# tconst
# tt3171176                    10.0  nm0936044
# tt3202670                    10.0  nm0774420
# tt2889050                    10.0  nm0024580
# tt6493644                    10.0  nm3629099
# tt3635300                    10.0  nm3324534
# tt4844348                    10.0  nm2465962
# tt5582876                    10.0  nm0040630
# tt5544384                    10.0  nm2423816
# tt5797820                    10.0  nm2709019
# tt4331318                    10.0  nm1292833
#
#                                                      writers  directors_count  \
# tconst
# tt3171176                      nm5929911,nm0740427,nm0936044              1.0
# tt3202670                      nm0584770,nm0410707,nm0109730              1.0
# tt2889050  nm2385292,nm0024580,nm5658465,nm0502412,nm5926435              1.0
# tt6493644                                          nm8616760              1.0
# tt3635300  nm6394985,nm7359828,nm3324534,nm6394986,nm6394987              1.0
# tt4844348                                nm0542493,nm2465962              1.0
# tt5582876                                          nm0040630              1.0
# tt5544384                      nm2423816,nm4986613,nm0902135              1.0
# tt5797820                                          nm8066791              1.0
# tt4331318                                nm1305724,nm1292833              1.0
#
#            writers_count  averageRating  numVotes             rating  \
# tconst
# tt3171176            3.0            4.1     498.0   Wait for Netflix
# tt3202670            3.0            5.5     279.0   Wait for Netflix
# tt2889050            5.0            5.9     509.0   Wait for Netflix
# tt6493644            1.0            6.4     156.0   Wait for Netflix
# tt3635300            5.0            3.3      32.0   Wait for Netflix
# tt4844348            2.0            6.7      64.0   Wait for Netflix
# tt5582876            1.0            2.7     709.0   Wait for Netflix
# tt5544384            3.0            7.4    2933.0  Buy cinema ticket
# tt5797820            1.0            6.1     559.0   Wait for Netflix
# tt4331318            2.0            6.1     310.0   Wait for Netflix
#
#                                                     raw_text  \
# tconst
# tt3171176  female soldier: towards that exit! cafferty: h...
# tt3202670
# tt2889050  they are highly specialized and social animals...
# tt6493644  ﻿ you really have to do something. i have aske...
# tt3635300  - all right, lets see. . move the light, mate....
# tt4844348
# tt5582876  1 in the name of ben-hur subrip: pix this is e...
# tt5544384  https://t.me/rickychannel its a shame you cant...
# tt5797820  this movie is a fiction based on real facts. s...
# tt4331318  1 this film is based on a true story. nonethel...
#
#                                                 preproc_text
# tconst
# tt3171176  female soldier towards exit cafferty hey dont ...
# tt3202670
# tt2889050  highly_specialized social animal hydrodynamic_...
# tt6493644  really something ask since month_ago third tim...
# tt3635300  all_right let see move light mate all_right th...
# tt4844348
# tt5582876  name ben-hur_subrip pix exactly whats_wrong to...
# tt5544384  http //t.me/rickychannel shame cant see star a...
# tt5797820  movie fiction base real fact character dialogu...
# tt4331318  film base true story nonetheless work fiction ...
